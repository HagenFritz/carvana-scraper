# %%
import argparse
import logging
import pathlib
import sys
import os
sys.path.append('../')
import json

import pandas as pd

from webdriver_manager.chrome import ChromeDriverManager

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, TimeoutException
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as EC

from src.scrape.scraper import Scraper

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Importing and Working with Filters from JSON

# %%
with open('../data/filters.json') as f:
        filters = json.load(f)

# %%
filters
# Out:
# {'price_range': {'min': 0, 'max': 40000},
#  'make': ['Alfa Romeo', 'Saab'],
#  'body_type': ['Suv', 'Sedan', 'Hatchback', 'Truck', 'Wagon'],
#  'year': {'min': 2015, 'max': 2022}}

# %% [markdown]
# ### Test Results

# %%
with open("../data/processed/available_cars.json") as f:
    test_data = json.load(f)

for key in test_data.keys():
    print(key ,": ",len(test_data[key]))
# Out:
# make :  2040
# model :  2040
# year :  2040
# trim :  2040
# mileage :  2040
# price :  2040
# monthly_payment :  2040
# status :  0
# link :  2040

# %% [markdown]
# ## Determining Filter Hierarchy
# We need to determine what order we want to loop through the filters:
# 1. **Price and Year**: Since these are unchanging, we set these first
# 2. **Make**
# 3. **Body Type**

# %%
filters["price_range"]["min"]
# Out:
# 0

# %%
filters["make"]
# Out:
# ['Alfa Romeo', 'Saab']

# %% [markdown]
# # Getting Vehicle Details with BeautifulSoup

# %%
from bs4 import BeautifulSoup

# %%
scraper = Scraper()
scraper.driver.get("https://www.carvana.com/cars/chevrolet?email-capture=&page=7")
html = scraper.driver.page_source # get the html source
soup = BeautifulSoup(html, 'html.parser') # save as a BS object

# %%
year_makes = soup.find_all("div",{"class","year-make"})
#print(year_makes)
trim_mileages = soup.find_all("div",{"class","trim-mileage"})
#print(trim_mileages)
prices = soup.find_all("div",{"class","flex items-end font-bold mb-4 text-2xl"})
print(prices)
monthly_payments = soup.find_all("div",{"class","monthly-payment"})
#print(monthly_payments)
cars = soup.find_all("div",{"class","result-tile"})
#print(cars)

results = {
    "make":[],
    "model":[],
    "year":[],
    "trim":[],
    "mileage":[],
    "price":[],
    "monthly_payment":[],
    "link":[]
}
for year_make, trim_mileage, price, monthly_payment, car in zip(year_makes, trim_mileages, prices, monthly_payments, cars):

    print(year_make)
    simplified_year_make = [item for item in year_make.contents if item != " "]
    print(simplified_year_make)
    for key, val in zip(["year","make","model"],[simplified_year_make[0],simplified_year_make[1],simplified_year_make[2]]):
        print(key, val)
        results[key].append(val)

    trim = trim_mileage.findChildren("span")[0].contents[0]
    mileage = trim_mileage.findChildren("span")[1].contents[0]
    for key, val in zip(["trim","mileage"],[trim,mileage]):
        results[key].append(val)

    results["price"].append(price.contents[-1])

    payment = monthly_payment.findChildren("span")[0].contents
    results["monthly_payment"].append([item for item in payment if item != " "][1])

    hrefs = car.find_all("a",href=True)
    for ref in hrefs:
        results["link"].append(f"www.carvana.com{ref['href']}")
    
pd.DataFrame(results)
# Out:
# [<div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$17,990</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$14,990</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$14,590</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$21,590</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$17,990</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$14,590</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$18,590</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$17,590</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$22,990</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$14,990</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$14,590</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$15,590</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$22,990</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$17,990</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$19,990</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$22,590</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$15,990</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$13,990</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$15,990</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$16,590</div>, <div class="flex items-end font-bold mb-4 text-2xl" data-qa="price" data-test="Price" data-testid="price">$15,990</div>]
# <div class="year-make">2011<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Volt</div>
# ['2011', 'Chevrolet', 'Volt']
# year 2011
# make Chevrolet
# model Volt
# <div class="year-make">2013<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Cruze</div>
# ['2013', 'Chevrolet', 'Cruze']
# year 2013
# make Chevrolet
# model Cruze
# <div class="year-make">2013<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Spark</div>
# ['2013', 'Chevrolet', 'Spark']
# year 2013
# make Chevrolet
# model Spark
# <div class="year-make">2020<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Malibu</div>
# ['2020', 'Chevrolet', 'Malibu']
# year 2020
# make Chevrolet
# model Malibu
# <div class="year-make">2016<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Cruze</div>
# ['2016', 'Chevrolet', 'Cruze']
# year 2016
# make Chevrolet
# model Cruze
# <div class="year-make">2015<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Spark EV</div>
# ['2015', 'Chevrolet', 'Spark EV']
# year 2015
# make Chevrolet
# model Spark EV
# <div class="year-make">2017<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Trax</div>
# ['2017', 'Chevrolet', 'Trax']
# year 2017
# make Chevrolet
# model Trax
# <div class="year-make">2015<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Trax</div>
# ['2015', 'Chevrolet', 'Trax']
# year 2015
# make Chevrolet
# model Trax
# <div class="year-make">2019<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Equinox</div>
# ['2019', 'Chevrolet', 'Equinox']
# year 2019
# make Chevrolet
# model Equinox
# <div class="year-make">2014<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Volt</div>
# ['2014', 'Chevrolet', 'Volt']
# year 2014
# make Chevrolet
# model Volt
# <div class="year-make">2017<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Spark</div>
# ['2017', 'Chevrolet', 'Spark']
# year 2017
# make Chevrolet
# model Spark
# <div class="year-make">2019<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Spark</div>
# ['2019', 'Chevrolet', 'Spark']
# year 2019
# make Chevrolet
# model Spark
# <div class="year-make">2020<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Impala</div>
# ['2020', 'Chevrolet', 'Impala']
# year 2020
# make Chevrolet
# model Impala
# <div class="year-make">2015<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Malibu</div>
# ['2015', 'Chevrolet', 'Malibu']
# year 2015
# make Chevrolet
# model Malibu
# <div class="year-make">2020<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Malibu</div>
# ['2020', 'Chevrolet', 'Malibu']
# year 2020
# make Chevrolet
# model Malibu
# <div class="year-make">2018<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Volt</div>
# ['2018', 'Chevrolet', 'Volt']
# year 2018
# make Chevrolet
# model Volt
# <div class="year-make">2015<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Cruze</div>
# ['2015', 'Chevrolet', 'Cruze']
# year 2015
# make Chevrolet
# model Cruze
# <div class="year-make">2016<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Cruze Limited</div>
# ['2016', 'Chevrolet', 'Cruze Limited']
# year 2016
# make Chevrolet
# model Cruze Limited
# <div class="year-make">2017<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Equinox</div>
# ['2017', 'Chevrolet', 'Equinox']
# year 2017
# make Chevrolet
# model Equinox
# <div class="year-make">2018<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Trax</div>
# ['2018', 'Chevrolet', 'Trax']
# year 2018
# make Chevrolet
# model Trax
# <div class="year-make">2015<!-- --> <!-- -->Chevrolet<!-- --> <!-- -->Malibu</div>
# ['2015', 'Chevrolet', 'Malibu']
# year 2015
# make Chevrolet
# model Malibu
#          make          model  year     trim mileage    price monthly_payment  \
# 0   Chevrolet           Volt  2011     base  14,818  $17,990             355
# 1   Chevrolet          Cruze  2013       LT  35,283  $14,990             305
# 2   Chevrolet          Spark  2013       LT  62,195  $14,590             298
# 3   Chevrolet         Malibu  2020       LT  45,817  $21,590             419
# 4   Chevrolet          Cruze  2016       LS  11,871  $17,990             355
# 5   Chevrolet       Spark EV  2015      2LT  40,086  $14,590             282
# 6   Chevrolet           Trax  2017       LT  40,080  $18,590             348
# 7   Chevrolet           Trax  2015       LT  35,008  $17,590             330
# 8   Chevrolet        Equinox  2019  Premier  53,290  $22,990             446
# 9   Chevrolet           Volt  2014     base  80,009  $14,990             293
# 10  Chevrolet          Spark  2017       LS  48,901  $14,590             290
# 11  Chevrolet          Spark  2019       LS  31,493  $15,590             300
# 12  Chevrolet         Impala  2020       LT  51,844  $22,990             446
# 13  Chevrolet         Malibu  2015       LT  46,356  $17,990             347
# 14  Chevrolet         Malibu  2020       LT  56,213  $19,990             390
# 15  Chevrolet           Volt  2018       LT  53,458  $22,590             424
# 16  Chevrolet          Cruze  2015      2LT  48,056  $15,990             317
# 17  Chevrolet  Cruze Limited  2016       LS  70,276  $13,990             279
# 18  Chevrolet        Equinox  2017       LS  97,549  $15,990             321
# 19  Chevrolet           Trax  2018       LT  70,110  $16,590             321
# 20  Chevrolet         Malibu  2015       LT  84,459  $15,990             329
#
#                                link
# 0   www.carvana.com/vehicle/2545288
# 1   www.carvana.com/vehicle/2539220
# 2   www.carvana.com/vehicle/2535892
# 3   www.carvana.com/vehicle/2418142
# 4   www.carvana.com/vehicle/2535995
# 5   www.carvana.com/vehicle/2536352
# 6   www.carvana.com/vehicle/2466311
# 7   www.carvana.com/vehicle/2483584
# 8   www.carvana.com/vehicle/2576440
# 9   www.carvana.com/vehicle/2535020
# 10  www.carvana.com/vehicle/2532053
# 11  www.carvana.com/vehicle/2494782
# 12  www.carvana.com/vehicle/2545592
# 13  www.carvana.com/vehicle/2529617
# 14  www.carvana.com/vehicle/2291047
# 15  www.carvana.com/vehicle/2487279
# 16  www.carvana.com/vehicle/2500231
# 17  www.carvana.com/vehicle/2508396
# 18  www.carvana.com/vehicle/2486195
# 19  www.carvana.com/vehicle/2493098
# 20  www.carvana.com/vehicle/2534536

# %%
year_makes = soup.find_all("div",{"class","year-make"})
print(year_makes[0].contents)
# Out:
# ['2011', ' ', ' ', ' ', 'Chevrolet', ' ', ' ', ' ', 'Volt']

# %%
for trim_mileage in trim_mileages:
    trim = trim_mileage.findChildren("span")[0].contents
    mileage = trim_mileage.findChildren("span")[1].contents

# %%
pages = soup.find_all("span",{"class":"paginationstyles__PaginationText-mpry3x-5 iXXOCI"})
nav = pages[0].contents[0].split(" ")
nav[1] == nav[-1]
# Out:
# False

# %%
cars = soup.find_all("div",{"class","result-tile"})
for car in cars:
    hrefs = car.find_all("a",href=True)
    for ref in hrefs:
        print(f"www.carvana.com{ref['href']}")
    status_message = car.find_all("div",{"class","days-to-delivery days-to-delivery"})
    print(status_message[0].contents)
# Out:
# www.carvana.com/vehicle/2420612
# ['Get it by Thursday']
# www.carvana.com/vehicle/2375292
# ['Get it by Thursday']
# www.carvana.com/vehicle/2254728
# ['Get it by Thursday']
# www.carvana.com/vehicle/2457433
# ['Get it by Thursday']
# www.carvana.com/vehicle/2424996
# ['Get it by Thursday']
# www.carvana.com/vehicle/2466397
# ['Get it by Thursday']
# www.carvana.com/vehicle/2469624
# ['Get it by Thursday']
# www.carvana.com/vehicle/2336254
# ['Get it by Thursday']
# www.carvana.com/vehicle/2475544
# ['Get it by Thursday']
# www.carvana.com/vehicle/2465075
# ['Get it by Thursday']
# www.carvana.com/vehicle/2474543
# ['Get it by Thursday']
# www.carvana.com/vehicle/2368806
# ['Get it by Thursday']
# www.carvana.com/vehicle/2377063
# ['Get it by Thursday']
# www.carvana.com/vehicle/2296827
# ['Get it by Thursday']
# www.carvana.com/vehicle/2331217
# ['Get it by Thursday']
# www.carvana.com/vehicle/2435996
# ['Get it by Thursday']
# www.carvana.com/vehicle/2432943
# ['Get it by Thursday']
# www.carvana.com/vehicle/2231399
# ['Get it by Thursday']
# www.carvana.com/vehicle/2370548
# ['Get it by Thursday']
# www.carvana.com/vehicle/2363593
# ['Get it by Thursday']

# %%
# days to delivery
statuses = soup.find_all("div",{"class","days-to-delivery days-to-delivery"})
for status in statuses:
    print(status.contents)
# Out:
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']
# ['Get it by Thursday']

# %%
# purchase in progress
statuses = soup.find_all("div",{"class","purchase-callout text-only locked"})
for status in statuses:
    print(status.contents)

# %%
for payment in monthly_payments:
    print(payment.findChildren("span")[0].contents)
# Out:
# ['$', ' ', '415', ' ', '/mo']
# ['$', ' ', '420', ' ', '/mo']
# ['$', ' ', '369', ' ', '/mo']
# ['$', ' ', '336', ' ', '/mo']
# ['$', ' ', '443', ' ', '/mo']
# ['$', ' ', '446', ' ', '/mo']
# ['$', ' ', '355', ' ', '/mo']
# ['$', ' ', '460', ' ', '/mo']
# ['$', ' ', '380', ' ', '/mo']
# ['$', ' ', '449', ' ', '/mo']
# ['$', ' ', '427', ' ', '/mo']
# ['$', ' ', '341', ' ', '/mo']
# ['$', ' ', '415', ' ', '/mo']
# ['$', ' ', '450', ' ', '/mo']
# ['$', ' ', '321', ' ', '/mo']
# ['$', ' ', '360', ' ', '/mo']
# ['$', ' ', '340', ' ', '/mo']
# ['$', ' ', '328', ' ', '/mo']
# ['$', ' ', '288', ' ', '/mo']
# ['$', ' ', '320', ' ', '/mo']
